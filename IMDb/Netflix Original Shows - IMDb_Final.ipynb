# %%
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd

# %%
def init_browser():
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    return Browser('chrome', **executable_path, headless=False)

# %%
#create show info list - get rank, title, star rating - store into dictionary 
show_info = []
rank = 0
browser = init_browser()

for x in range(1,3):
    #Scrape page into Soup
    url = f'https://www.imdb.com/list/ls063868333/?page={x}'
    browser.visit(url)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    
    time.sleep(1)
    
    #get all shows
    top_shows=soup.find_all('div', class_='lister-item mode-detail')
    

    for each_show in top_shows: 
        show_dict = {}
        rank = rank+1
        show_dict['rank'] = rank
        show_dict['title'] = each_show.find('h3', class_='lister-item-header').a.text
        show_dict['rating'] = each_show.find('span', class_='ipl-rating-star__rating').text
        show_info.append(show_dict)
    
browser.quit()

# %%
show_info
# Out:
# [{'rank': 1, 'title': 'Our Planet', 'rating': '9.3'},
#  {'rank': 2, 'title': 'When They See Us', 'rating': '8.9'},
#  {'rank': 3, 'title': 'Stranger Things', 'rating': '8.8'},
#  {'rank': 4, 'title': 'House of Cards', 'rating': '8.7'},
#  {'rank': 5, 'title': 'Black Mirror', 'rating': '8.8'},
#  {'rank': 6, 'title': 'Narcos', 'rating': '8.8'},
#  {'rank': 7, 'title': 'Arrested Development', 'rating': '8.7'},
#  {'rank': 8, 'title': 'Sacred Games', 'rating': '8.7'},
#  {'rank': 9, 'title': 'Dark', 'rating': '8.7'},
#  {'rank': 10, 'title': 'The Haunting of Hill House', 'rating': '8.7'},
#  {'rank': 11, 'title': 'The Crown', 'rating': '8.7'},
#  {'rank': 12, 'title': 'BoJack Horseman', 'rating': '8.7'},
#  {'rank': 13, 'title': 'Daredevil', 'rating': '8.6'},
#  {'rank': 14, 'title': 'Mindhunter', 'rating': '8.6'},
#  {'rank': 15, 'title': 'Making a Murderer', 'rating': '8.6'},
#  {'rank': 16, 'title': 'Love, Death & Robots', 'rating': '8.5'},
#  {'rank': 17, 'title': 'Anne with an E', 'rating': '8.6'},
#  {'rank': 18, 'title': "Chef's Table", 'rating': '8.6'},
#  {'rank': 19, 'title': 'Formula 1: Drive to Survive', 'rating': '8.6'},
#  {'rank': 20, 'title': 'Money Heist', 'rating': '8.4'},
#  {'rank': 21, 'title': 'The Punisher', 'rating': '8.5'},
#  {'rank': 22, 'title': 'Unbelievable', 'rating': '8.5'},
#  {'rank': 23, 'title': 'The Mechanism', 'rating': '8.4'},
#  {'rank': 24, 'title': 'The Dark Crystal: Age of Resistance', 'rating': '8.5'},
#  {'rank': 25, 'title': 'Last Chance U', 'rating': '8.5'},
#  {'rank': 26, 'title': 'Trollhunters: Tales of Arcadia', 'rating': '8.4'},
#  {'rank': 27, 'title': 'After Life', 'rating': '8.5'},
#  {'rank': 28, 'title': 'Narcos: Mexico', 'rating': '8.4'},
#  {'rank': 29, 'title': 'Trailer Park Boys', 'rating': '8.4'},
#  {'rank': 30, 'title': 'The Dragon Prince', 'rating': '8.4'},
#  {'rank': 31, 'title': 'The Witcher', 'rating': '8.3'},
#  {'rank': 32, 'title': 'Sense8', 'rating': '8.3'},
#  {'rank': 33, 'title': 'Ozark', 'rating': '8.4'},
#  {'rank': 34, 'title': 'Sex Education', 'rating': '8.3'},
#  {'rank': 35, 'title': 'Master of None', 'rating': '8.3'},
#  {'rank': 36, 'title': 'The Last Kingdom', 'rating': '8.4'},
#  {'rank': 37, 'title': 'Atypical', 'rating': '8.3'},
#  {'rank': 38, 'title': 'Godless', 'rating': '8.3'},
#  {'rank': 39, 'title': 'Grace and Frankie', 'rating': '8.3'},
#  {'rank': 40, 'title': 'Longmire', 'rating': '8.3'},
#  {'rank': 41, 'title': 'The Get Down', 'rating': '8.3'},
#  {'rank': 42, 'title': 'Kingdom', 'rating': '8.3'},
#  {'rank': 43, 'title': 'Lucifer', 'rating': '8.2'},
#  {'rank': 44, 'title': 'The Killing', 'rating': '8.2'},
#  {'rank': 45, 'title': 'Castlevania', 'rating': '8.2'},
#  {'rank': 46, 'title': 'American Vandal', 'rating': '8.2'},
#  {'rank': 47, 'title': 'Wild Wild Country', 'rating': '8.2'},
#  {'rank': 48, 'title': 'The Kominsky Method', 'rating': '8.2'},
#  {'rank': 49, 'title': 'One Day at a Time', 'rating': '8.2'},
#  {'rank': 50, 'title': 'Orange Is the New Black', 'rating': '8.1'},
#  {'rank': 51, 'title': 'Altered Carbon', 'rating': '8.1'},
#  {'rank': 52, 'title': 'The End of the F***ing World', 'rating': '8.1'},
#  {'rank': 53, 'title': 'Star Wars: The Clone Wars', 'rating': '8.1'},
#  {'rank': 54, 'title': 'Travelers', 'rating': '8.1'},
#  {'rank': 55, 'title': 'Dead to Me', 'rating': '8.1'},
#  {'rank': 56,
#   'title': "Don't F**k with Cats: Hunting an Internet Killer",
#   'rating': '8.1'},
#  {'rank': 57, 'title': 'The Keepers', 'rating': '8.1'},
#  {'rank': 58, 'title': 'Lovesick', 'rating': '8.1'},
#  {'rank': 59, 'title': 'Comedians in Cars Getting Coffee', 'rating': '8.1'},
#  {'rank': 60, 'title': 'On My Block', 'rating': '8.1'},
#  {'rank': 61, 'title': 'Voltron: Legendary Defender', 'rating': '8.1'},
#  {'rank': 62, 'title': 'Dirty Money', 'rating': '8.1'},
#  {'rank': 63, 'title': 'Jessica Jones', 'rating': '8'},
#  {'rank': 64, 'title': 'The Umbrella Academy', 'rating': '7.9'},
#  {'rank': 65, 'title': 'Marco Polo', 'rating': '8'},
#  {'rank': 66, 'title': 'Big Mouth', 'rating': '8'},
#  {'rank': 67, 'title': 'Bloodline', 'rating': '8'},
#  {'rank': 68, 'title': 'GLOW', 'rating': '8'},
#  {'rank': 69, 'title': 'Lilyhammer', 'rating': '8'},
#  {'rank': 70, 'title': 'F Is for Family', 'rating': '8'},
#  {'rank': 71, 'title': 'Rise of Empires: Ottoman', 'rating': '8'},
#  {'rank': 72, 'title': 'DreamWorks Dragons', 'rating': '8'},
#  {'rank': 73, 'title': 'Suburra: Blood on Rome', 'rating': '8'},
#  {'rank': 74,
#   'title': "Inside Bill's Brain: Decoding Bill Gates",
#   'rating': '8'},
#  {'rank': 75, 'title': 'The OA', 'rating': '7.9'},
#  {'rank': 76, 'title': 'Russian Doll', 'rating': '7.9'},
#  {'rank': 77, 'title': 'The Spy', 'rating': '7.9'},
#  {'rank': 78, 'title': 'The Staircase', 'rating': '7.9'},
#  {'rank': 79, 'title': 'How to Sell Drugs Online (Fast)', 'rating': '7.9'},
#  {'rank': 80, 'title': 'Undercover', 'rating': '7.9'},
#  {'rank': 81, 'title': '13 Reasons Why', 'rating': '7.8'},
#  {'rank': 82, 'title': 'You', 'rating': '7.8'},
#  {'rank': 83, 'title': 'Maniac', 'rating': '7.8'},
#  {'rank': 84, 'title': 'Santa Clarita Diet', 'rating': '7.8'},
#  {'rank': 85, 'title': 'A Series of Unfortunate Events', 'rating': '7.8'},
#  {'rank': 86, 'title': 'Alias Grace', 'rating': '7.8'},
#  {'rank': 87,
#   'title': 'Conversations with a Killer: The Ted Bundy Tapes',
#   'rating': '7.8'},
#  {'rank': 88, 'title': 'El Chapo', 'rating': '7.8'},
#  {'rank': 89, 'title': 'Love', 'rating': '7.7'},
#  {'rank': 90, 'title': 'Messiah', 'rating': '7.7'},
#  {'rank': 91, 'title': 'Gilmore Girls: A Year in the Life', 'rating': '7.7'},
#  {'rank': 92, 'title': 'I Am Not Okay with This', 'rating': '7.6'},
#  {'rank': 93, 'title': 'The Gift', 'rating': '7.6'},
#  {'rank': 94, 'title': 'Seven Seconds', 'rating': '7.7'},
#  {'rank': 95, 'title': 'Cable Girls', 'rating': '7.7'},
#  {'rank': 96, 'title': 'Spinning Out', 'rating': '7.7'},
#  {'rank': 97, 'title': 'Damnation', 'rating': '7.7'},
#  {'rank': 98, 'title': 'Designated Survivor', 'rating': '7.5'},
#  {'rank': 99, 'title': 'Chilling Adventures of Sabrina', 'rating': '7.6'},
#  {'rank': 100, 'title': 'Unbreakable Kimmy Schmidt', 'rating': '7.6'},
#  {'rank': 101, 'title': 'Elite', 'rating': '7.6'},
#  {'rank': 102,
#   'title': "Evil Genius: The True Story of America's Most Diabolical Bank Heist",
#   'rating': '7.6'},
#  {'rank': 103, 'title': 'The Politician', 'rating': '7.5'},
#  {'rank': 104, 'title': 'The Devil Next Door', 'rating': '7.6'},
#  {'rank': 105, 'title': 'The Ranch', 'rating': '7.5'},
#  {'rank': 106, 'title': 'Quicksand', 'rating': '7.5'},
#  {'rank': 107, 'title': 'Everything Sucks!', 'rating': '7.5'},
#  {'rank': 108, 'title': 'Ragnarok', 'rating': '7.5'},
#  {'rank': 109, 'title': 'Marianne', 'rating': '7.5'},
#  {'rank': 110, 'title': 'Dogs of Berlin', 'rating': '7.5'},
#  {'rank': 111, 'title': 'Virgin River', 'rating': '7.5'},
#  {'rank': 112, 'title': 'Locke & Key', 'rating': '7.4'},
#  {'rank': 113,
#   'title': 'Wet Hot American Summer: First Day of Camp',
#   'rating': '7.4'},
#  {'rank': 114, 'title': 'The Stranger', 'rating': '7.4'},
#  {'rank': 115, 'title': '3%', 'rating': '7.4'},
#  {'rank': 116, 'title': 'Glitch', 'rating': '7.4'},
#  {'rank': 117,
#   'title': 'Killer Inside: The Mind of Aaron Hernandez',
#   'rating': '7.4'},
#  {'rank': 118, 'title': 'Criminal: UK', 'rating': '7.4'},
#  {'rank': 119, 'title': 'Luke Cage', 'rating': '7.3'},
#  {'rank': 120, 'title': 'The Defenders', 'rating': '7.3'},
#  {'rank': 121, 'title': 'Lost in Space', 'rating': '7.3'},
#  {'rank': 122, 'title': 'Safe', 'rating': '7.3'},
#  {'rank': 123, 'title': 'Living with Yourself', 'rating': '7.2'},
#  {'rank': 124, 'title': 'La forêt', 'rating': '7.3'},
#  {'rank': 125, 'title': 'Disenchantment', 'rating': '7.2'}]

# %%
shows = show_info
showDF = pd.DataFrame(shows)
showDF.set_index('rank', inplace=True)
showDF.head()
# Out:
#                  title rating
# rank
# 1           Our Planet    9.3
# 2     When They See Us    8.9
# 3      Stranger Things    8.8
# 4       House of Cards    8.7
# 5         Black Mirror    8.8

# %%
showDF.to_csv('show.csv', encoding='utf-8')
